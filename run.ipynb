# %%
# !nvitop
# Out:
# )07=Mon Jun 23 20:25:08 2025
# ╒═════════════════════════════════════════════════════════════════════════════╕
# │ NVITOP 1.3.2      Driver Version: 570.124.06      CUDA Driver Version: 12.8 │
# ├───────────────────────────────┬──────────────────────┬──────────────────────┤
# │ GPU  Name        Persistence-M│ Bus-Id        Disp.A │ Volatile Uncorr. ECC │
# │ Fan  Temp  Perf  Pwr:Usage/Cap│         Memory-Usage │ GPU-Util  Compute M. │
# ╞═══════════════════════════════╪══════════════════════╪══════════════════════╡
# │   0  RTX A5000           Off  │ 00000000:3B:00.0 Off │                  N/A │
# │ 30%   40C    P8    28W / 230W │   3877MiB / 23.99GiB │      0%      Default │
# ├───────────────────────────────┼──────────────────────┼──────────────────────┤
# │   1  RTX A5000           Off  │ 00000000:5E:00.0 Off │                  N/A │
# │ 30%   61C    P0   105W / 230W │  23.17GiB / 23.99GiB │     35%      Default │
# ...

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 11.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 11.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 11.3 MB/s eta 0:00:00a 0:00:01
# ...
#   WARNING: The script sqlformat is installed in '/home/jupyter-23522029/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/60 [shortuuid]  WARNING: The script shortuuid is installed in '/home/jupyter-23522029/.local/bin' which is not on PATH.
# ...

# %%
# !export CUDA_VISIBLE_DEVICES=0 && python finetune_indonli.py
# Out:
# 2025-06-23 20:30:31.608416: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 20:30:31.611200: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 20:30:31.663376: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 20:30:32.629801: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading IndoNLI dataset...
# Dataset loaded.
# DatasetDict({
#     train: Dataset({
# ...

# %%
# !ls
# Out:
# 1748859291991_Eksplorasi-MLOps-Tools.pdf  mlruns		run.ipynb
# Experiment_Tracking			  requirements.txt	tugas.txt
# finetune_indonli.py			  results_indobert
# metrics					  results_indoreoberta

# %%
# !cd .. && zip -r logging_experiment.zip logging_experiment
# Out:
#   adding: logging_experiment/ (stored 0%)
#   adding: logging_experiment/tugas.txt (deflated 62%)
#   adding: logging_experiment/metrics/ (stored 0%)
#   adding: logging_experiment/metrics/roberta_metrics.json (deflated 37%)
#   adding: logging_experiment/metrics/bert_metrics.json (deflated 37%)
#   adding: logging_experiment/results_indoreoberta/ (stored 0%)
#   adding: logging_experiment/results_indoreoberta/runs/ (stored 0%)
#   adding: logging_experiment/results_indoreoberta/runs/Jun23_20-25-39_tambora/ (stored 0%)
#   adding: logging_experiment/results_indoreoberta/runs/Jun23_20-25-39_tambora/events.out.tfevents.1750685142.tambora.3518442.0 (deflated 62%)
#   adding: logging_experiment/results_indoreoberta/runs/Jun23_20-30-01_tambora/ (stored 0%)
#   adding: logging_experiment/results_indoreoberta/runs/Jun23_20-30-01_tambora/events.out.tfevents.1750685404.tambora.3519389.0 (deflated 62%)
# ...

# %%
# !rm -rf thesis stanza_resources personal
